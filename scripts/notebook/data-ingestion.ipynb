# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader, WebBaseLoader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader = PyPDFLoader("/mnt/d/Project/agentic-tool-LangGraph-kn/data/RABINDRANATH-TAGORE.pdf")

# %%
doc = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'Acrobat PDFWriter 3.0 for Windows', 'creator': 'Microsoft Word', 'creationdate': 'Friday, 30. April 1999 11:47', 'title': 'Rabindranath Tagore', 'author': 'Jha, Narmadeshwar', 'keywords': 'Educational theories; philosophy of education; history of education; biographies', 'subject': 'Thinkers on education', 'moddate': '2001-01-17T16:42:59+01:00', 'source': '/mnt/d/Project/agentic-tool-LangGraph-kn/data/RABINDRANATH-TAGORE.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}, page_content='1\nThe following text was originally published in PROSPECTS: the quarterly review of education\n(Paris, UNESCO: International Bureau of Education), vol. XXIV, no. 3/4, 1994, p. 603–19.\n©UNESCO:International Bureau of Education, 1999\nThis document may be reproduced free of charge as long as acknowledgement is made of the source.\nRABINDRANATH TAGORE 1\n(1861–1941)\nNarmadeshwar Jha\nFamily background and early influences\nRabindranath Tagore was born on 7 May 1861.
# ...

# %%
import bs4

# %%
wbloader = WebBaseLoader(web_paths=["https://www.britannica.com/biography/Rabindranath-Tagore"],)

# %%
wbdocs = wbloader.load()

# %%
wbdocs[0].model_dump()
# Out:
# {'id': None,
#  'metadata': {'source': 'https://www.britannica.com/biography/Rabindranath-Tagore',
#   'title': 'Rabindranath Tagore | Biography, Poems, Short Stories, Nobel Prize, & Facts | Britannica',
#   'description': 'Rabindranath Tagore, the revered Bengali poet and polymath, left an enduring legacy through his profound literary works and became the first non-European Nobel laureate in Literature.',
#   'language': 'en'},
# ...
